# %% [markdown]
# # DeepMuisic v3 Grid Experiments (Without SNR)
# This notebook clones the repo into Google Drive, then runs the post-SNR experiment groups with `run_grid.py` and early stopping enabled by config/runner.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !mkdir -p deepmusic_workspace
# %cd /content/drive/MyDrive/deepmusic_workspace
# !git clone https://github.com/alyssa2024/DeepMuisic.git || true
# %cd /content/drive/MyDrive/deepmusic_workspace/DeepMuisic
# !git fetch --all
# !git checkout v3
# !git pull
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/deepmusic_workspace
# Cloning into 'DeepMuisic'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 132 (delta 73), reused 101 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 108.29 KiB | 1.41 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# /content/drive/MyDrive/deepmusic_workspace/DeepMuisic
# Fetching origin
# Branch 'v3' set up to track remote branch 'v3' from 'origin'.
# Switched to a new branch 'v3'
# Already up to date.

# %% [markdown]
# ## Run Post-SNR Experiment Groups
# Includes: Exp2, Exp3A/3B, Exp4, Exp5A/5B/5C.

# %%
# %cd /content/drive/MyDrive/deepmusic_workspace/DeepMuisic
# !python run_grid.py --model_name complex_ls --experiment exp2_n_revs --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp3a_window_revs --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp3b_num_probes --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp4_num_harmonics --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp5a_prior_center_shift --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp5b_prior_band --pure_ls
# !python run_grid.py --model_name complex_ls --experiment exp5c_speed_fluctuation --pure_ls
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# epoch=0043 train_loss=0.004817 train_recon=0.004337 train_kl=47.958854 res_norm=0.000000e+00 res_scaled=0.000000e+00 res_rel=0.000000e+00 | f_mean=503.7464
# f_mean per harmonic: [166.9758  340.99908 635.0309  871.97986]
# f_offset per harmonic: [-0.02419567 -0.00091934  0.03085709 -0.02012253]
# f_ratio per harmonic: [-1.6130449e-03 -6.1289480e-05  2.0571393e-03 -1.3415019e-03]
# epoch=0044 train_loss=0.004816 train_recon=0.004336 train_kl=47.978928 res_norm=0.000000e+00 res_scaled=0.000000e+00 res_rel=0.000000e+00 | f_mean=503.7469
# f_mean per harmonic: [167.00264 340.99744 634.9934  871.994  ]
# f_offset per harmonic: [ 0.00264454 -0.00253677 -0.00652695 -0.00603104]
# f_ratio per harmonic: [ 0.0001763  -0.00016912 -0.00043513 -0.00040207]
# Saved best checkpoint by freq_rmse_hz: /content/drive/MyDrive/deepmusic_results/v3/complex_ls/exp4_num_harmonics/K_4/seed_0/checkpoints/best_freq_rmse.pt
# ...

# %% [markdown]
# ## Plot Results
# Use `--metric_source best` to plot best-checkpoint metrics; use `last` if needed.

# %%
# %cd /content/drive/MyDrive/deepmusic_workspace/DeepMuisic
# !python plot_results.py --result_root /content/drive/MyDrive/deepmusic_results/v3 --metric_source best
# Out:
# /content/drive/MyDrive/deepmusic_workspace/DeepMuisic
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/all_results_best.csv
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp2_n_revs_freq_rmse_hz.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp2_n_revs_detection_success_rate.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp3a_window_revs_freq_rmse_hz.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp3a_window_revs_detection_success_rate.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp3b_num_probes_freq_rmse_hz.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp3b_num_probes_detection_success_rate.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp4_num_harmonics_freq_rmse_hz.png
# [SAVE] /content/drive/MyDrive/deepmusic_results/v3/figures/exp4_num_harmonics_detection_success_rate.png
# ...
