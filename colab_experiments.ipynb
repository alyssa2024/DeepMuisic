# %% [markdown]
# # DeepMuisic v3 Experiments
# This notebook runs the evaluation grid with metrics: `freq_rmse_hz` and `detection_success_rate` (success requires frequency error <= 1 Hz and amplitude error <= 0.1 mm for all K components).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/alyssa2024/DeepMuisic.git
# %cd /content/DeepMuisic
# !git checkout v3

# %%
# %cd /content/DeepMuisic
# !git pull
# !git checkout v3

# %%
# %cd /content/DeepMuisic
# !python run_grid.py --model_name complex_ls --experiment exp1_snr --seeds 0 --freq_tol_hz 1.0 --amp_tol_m 1e-4

# %%
# %cd /content/DeepMuisic
# !python run_grid.py --model_name complex_ls --experiment exp1_snr --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp2_n_revs --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp3a_window_revs --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp3b_num_probes --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp4_num_harmonics --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp5a_prior_center_shift --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp5b_prior_band --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4
# !python run_grid.py --model_name complex_ls --experiment exp5c_speed_fluctuation --seeds 0,1,2 --freq_tol_hz 1.0 --amp_tol_m 1e-4

# %% [markdown]
# ## Repeat for Other Models
# After switching code/config to `complex_ls_residual` or `independent_posterior`, rerun the same commands by only changing `--model_name`.

# %%
# %cd /content/DeepMuisic
# !python plot_results.py --result_root /content/drive/MyDrive/deepmusic_results/v3
